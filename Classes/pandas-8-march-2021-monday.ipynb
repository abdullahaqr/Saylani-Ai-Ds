# %%
import numpy as np
import pandas as pd

# %%
dictionary = {'students': ['Abdullah', 'Furqan', 'Nasir', 'Anas', 'Obaid'],
            'paper1': [78, 56, 90, 80, 46],
             'paper2': [67, 93, 76, 80, 46],
             'paper3': [45, 70, 90, 100, 89],}

frame = pd.DataFrame(dictionary)
frame
# Out:
#    students  paper1  paper2  paper3
# 0  Abdullah      78      67      45
# 1    Furqan      56      93      70
# 2     Nasir      90      76      90
# 3      Anas      80      80     100
# 4     Obaid      46      46      89

# %%
frame['Obtain Marks'] = [250, 280, 257, 189, 200]
frame
# Out:
#    students  paper1  paper2  paper3  Obtain Marks
# 0  Abdullah      78      67      45           250
# 1    Furqan      56      93      70           280
# 2     Nasir      90      76      90           257
# 3      Anas      80      80     100           189
# 4     Obaid      46      46      89           200

# %%
frame['Total'] = 300
frame
# Out:
#    students  paper1  paper2  paper3  Obtain Marks  Total
# 0  Abdullah      78      67      45           250    300
# 1    Furqan      56      93      70           280    300
# 2     Nasir      90      76      90           257    300
# 3      Anas      80      80     100           189    300
# 4     Obaid      46      46      89           200    300

# %%
frame['Obtain Marks 2'] = frame['paper1'] + frame.paper2 + frame['paper3']
frame
# Out:
#    students  paper1  paper2  paper3  Obtain Marks  Total  Obtain Marks 2
# 0  Abdullah      78      67      45           250    300             190
# 1    Furqan      56      93      70           280    300             219
# 2     Nasir      90      76      90           257    300             256
# 3      Anas      80      80     100           189    300             260
# 4     Obaid      46      46      89           200    300             181

# %%
frame['Result'] = frame['Obtain Marks 2'] > 200
frame
# Out:
#    students  paper1  paper2  paper3  Obtain Marks  Total  Obtain Marks 2  \
# 0  Abdullah      78      67      45           250    300             190
# 1    Furqan      56      93      70           280    300             219
# 2     Nasir      90      76      90           257    300             256
# 3      Anas      80      80     100           189    300             260
# 4     Obaid      46      46      89           200    300             181
#
#    Result
# 0   False
# 1    True
# 2    True
# 3    True
# 4   False

# %%
#list comprehension

frame['Result'] = ["Pass" if totalmark >= 200 else "Fail" for totalmark in frame['Obtain Marks 2'] ]
frame
# Out:
#    students  paper1  paper2  paper3  Obtain Marks  Total  Obtain Marks 2  \
# 0  Abdullah      78      67      45           250    300             190
# 1    Furqan      56      93      70           280    300             219
# 2     Nasir      90      76      90           257    300             256
# 3      Anas      80      80     100           189    300             260
# 4     Obaid      46      46      89           200    300             181
#
#   Result
# 0   Fail
# 1   Pass
# 2   Pass
# 3   Pass
# 4   Fail

# %%
# home task = individual subject ko check kar k pass fail show karna result mein (mark >= 50 for pass)

# %%
pop = {'Nevada': {2001: 2.4, 2002: 2.9 },
       'Ohio': {2000: 1.5, 2001: 1.7, 2002: 3.6 },
      }
df = pd.DataFrame(pop)
df
# Out:
#       Nevada  Ohio
# 2001     2.4   1.7
# 2002     2.9   3.6
# 2000     NaN   1.5
